# %% [markdown]
# ### Imports

# %%
#Libraries
from WebScraperPageCount import WebScraper
import pandas as pd
import os
import fnmatch
import tempfile
import psycopg2
from sqlalchemy import create_engine

os.environ['MPLCONFIGDIR'] = "/home/jovyan"
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Daten scrapen, Dataframe erstellen

# %%
    dfImmo = WebScraper().runImmo()
    dfHome = WebScraper().runHome()

    data = pd.concat([dfHome, dfImmo])
    data.to_excel('Output.xlsx', index=False)

# %% [markdown]
# ## 2. Datenbereinigung

# %%
data.head()
# Out:
#   Number of Rooms Size [m²] Price [CHF]               Street Zip Code  \
# 1             100       4.5        1590          Via Ronco 2     6883
# 3             138       4.5        1490       Klosterstieg 8     8240
# 4              80       3.5        1450    Via Bellinzona 1a     6512
# 5            None         5        1650         Lärchenweg 1     3363
# 6             110       5.5        2100  Industriestrasse 17     5033
#
#         City State
# 1  Novazzano   NaN
# 3   Thayngen   NaN
# 4  Giubiasco   NaN
# 5    Oberönz   NaN
# 6   Buchs AG   NaN

# %%
data.describe()
# Out:
#        Number of Rooms Size [m²] Price [CHF]              Street Zip Code  \
# count             7359      7359        7359                7359     7359
# unique             253       180         907                6014     1334
# top               None       3.5        1650  Seestrasse 119/121     9000
# freq               927      1847         100                  13      139
#
#          City State
# count    7359   943
# unique   1404    25
# top     Basel  Bern
# freq      342   236

# %% [markdown]
# #### 2.1 Leere und falsche Adresseinträge auf NaN setzen

# %%
import numpy as np

data['Street'].isnull().sum()
data_work = data
data_work['Street'].replace('', np.nan, inplace=True)
data_work['Street'].replace('None', np.nan, inplace=True)
data_work['Street'].replace('.', np.nan, inplace=True)
data_work['Street'].replace('44', np.nan, inplace=True)
data_work['Street'].replace('70', np.nan, inplace=True)
data_work['Price [CHF]'].replace('None', np.nan, inplace=True)

# %%
data_work.describe()
# Out:
#        Number of Rooms Size [m²] Price [CHF]              Street Zip Code  \
# count             7359      7359        7359                7359     7359
# unique             253       180         907                6014     1334
# top               None       3.5        1650  Seestrasse 119/121     9000
# freq               927      1847         100                  13      139
#
#          City State
# count    7359   943
# unique   1404    25
# top     Basel  Bern
# freq      342   236

# %% [markdown]
# #### 2.2 Nan Einträge löschen

# %%
data_work.dropna(subset=['Street','Price [CHF]'], inplace=True)

# %%
data_work.describe()
# Out:
#        Number of Rooms Size [m²] Price [CHF]              Street Zip Code  \
# count             7359      7359        7359                7359     7359
# unique             253       180         907                6014     1334
# top               None       3.5        1650  Seestrasse 119/121     9000
# freq               927      1847         100                  13      139
#
#          City State
# count    7359   943
# unique   1404    25
# top     Basel  Bern
# freq      342   236

# %%
# with pd.option_context('display.max_rows', None, 'display.max_columns', None):
#     display(data_work)

# %% [markdown]
# #### 2.3 Duplikate anhand von Adresse und Preis entfernen

# %%
data_cleansed = data_work.drop_duplicates(subset=['Price [CHF]', 'Street'])
data_cleansed.describe()
# Out:
#        Number of Rooms Size [m²] Price [CHF]         Street Zip Code   City  \
# count             6886      6886        6886           6886     6886   6886
# unique             253       155         907           6014     1334   1402
# top               None       3.5        1650  Vy d'Etra  35     6900  Basel
# freq               909      1807          95             11      128    327
#
#        State
# count    587
# unique    24
# top     Bern
# freq     171
